# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import io
import requests
import json
url = "https://olinda.bcb.gov.br/olinda/servico/Gepad_QuadrosGeraisInternet/versao/v1/odata/QuadroGeralInabilitados?$top=100&$format=json"
js = requests.get(url).content
print(js.decode("utf-8"))
# Out:
# {"@odata.context":"https://was-p.bcnet.bcb.gov.br/olinda/servico/Gepad_QuadrosGeraisInternet/versao/v1/odata$metadata#QuadroGeralInabilitados","value":[{"PAS":"103325","Nome":"ABELARDO MATOS DE PAIVA DIAS","CPF":"XXX568623XX","Penalidade":"INABILITAÇÃO","Prazo_em_anos":4.00,"Inicio_do_cumprimento":"2018-06-15","Prazo_final_penalidade":"2022-06-15"},{"PAS":"74308","Nome":"ADALBERTO SAVIOLI","CPF":"XXX954368XX","Penalidade":"INABILITAÇÃO","Prazo_em_anos":20.00,"Inicio_do_cumprimento":"2016-01-25","Prazo_final_penalidade":"2036-01-25"},{"PAS":"108412","Nome":"ADALVO MARTINS FILHO","CPF":"XXX566185XX","Penalidade":"INABILITAÇÃO","Prazo_em_anos":5.00,"Inicio_do_cumprimento":"2018-05-18","Prazo_final_penalidade":"2023-05-18"},{"PAS":"60722","Nome":"ADELAR FERREIRA ORTIZ","CPF":"XXX042739XX","Penalidade":"INABILITAÇÃO","Prazo_em_anos":12.00,"Inicio_do_cumprimento":"2015-08-04","Prazo_final_penalidade":"2027-08-04"},{"PAS":"58195","Nome":"ADELIO BAROFALDI","CPF":"XXX732519XX","Penalidade":"I
# ...

# %%
import pandas as pd
import io
import requests
url = "https://data.sfgov.org/resource/pyih-qa8i.csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)
# Out:
#      business_id                 business_name    business_address  \
# 0            835                Kam Po Kitchen     801 Broadway St
# 1            905          Working Girls' Cafe'      0259 Kearny St
# 2           1203             TAWAN'S THAI FOOD     4403 GEARY Blvd
# 3           1345                   Cordon Bleu  1574 California St
# 4           1352                   LA TORTILLA     495 Castro St B
# ..           ...                           ...                 ...
# 995         7538           FREDS LIQUOR & DELI         151 06th St
# 996         1972        KENTUCKY FRIED CHICKEN     4150 GEARY Blvd
# 997        58745     San Francisco Tennis Club         645 05th St
# 998         2785              G & L RESTAURANT      198 LELAND Ave
# 999         5853  RAOUL WALLENBERG HIGH SCHOOL          40 VEGA St
#
#      business_city business_state business_postal_code  business_latitude  \
# 0    San Francisco             CA                94133          37.797223
# ...

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.

# %% [markdown]
# ![UML](../images/UML.png)
