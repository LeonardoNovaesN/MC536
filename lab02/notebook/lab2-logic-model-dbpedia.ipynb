# %% [markdown]
# # Laboratório 2

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

urlMiracles = "https://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"
dataMiracles = requests.get(urlMiracles)
jsonMiracles = dataMiracles.json()

print(json.dumps(jsonMiracles, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
amado = jsonMiracles["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tent of Miracles: " + amado)
# Out:
# Autor de Tent of Miracles: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
import io
import requests
import json

url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Area 51"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
data_json = data.json()
print(json.dumps(data_json, indent=3))
# Out:
# [
#    {
#       "place_id": 257989283,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 9625443,
#       "boundingbox": [
#          "37.2031047",
#          "37.2902268",
#          "-115.9294293",
#          "-115.7478331"
#       ],
#       "lat": "37.2275859",
#       "lon": "-115.83850929376537",
#       "display_name": "Area 51, Lincoln County, Nevada, United States",
#       "class": "landuse",
#       "type": "military",
#       "importance": 0.7144089582991568
#    },
#    {
#       "place_id": 3350644,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 389726285,
#       "boundingbox": [
#          "37.2213038",
#          "37.2513038",
#          "-115.8270572",
#          "-115.7970572"
#       ],
#       "lat": "37.2363038",
#       "lon": "-115.8120572",
#       "display_name": "Air Force Flight Test Center (Detachment 3), 4th Street, Lincoln County, Nevada, United States",
#       "class": "aeroway",
#       "type": "aerodrome",
#       "importance": 0.5144089582991568,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//transport_airport2.p.20.png"
#    },
#    {
#       "place_id": 240265414,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 762756222,
#       "boundingbox": [
#          "-13.9082988",
#          "-13.9002024",
#          "33.7376503",
#          "33.7511053"
#       ],
#       "lat": "-13.9040826",
#       "lon": "33.74461984574862",
#       "display_name": "Area 51, Lilongwe, Central Region, Malawi",
#       "class": "landuse",
#       "type": "residential",
#       "importance": 0.39999999999999997
#    },
#    {
#       "place_id": 177436941,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 374758444,
#       "boundingbox": [
#          "45.9770103",
#          "45.9783038",
#          "10.9463308",
#          "10.9468834"
#       ],
#       "lat": "45.9776198",
#       "lon": "10.9464864",
#       "display_name": "Area 51, Dro, Comunit\u00e0 Alto Garda e Ledro, Provincia di Trento, Trentino-Alto Adige/S\u00fcdtirol, 38074, Italia",
#       "class": "natural",
#       "type": "cliff",
#       "importance": 0.39999999999999997
#    },
#    {
#       "place_id": 302796299,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 902187482,
#       "boundingbox": [
#          "-46.8849897",
#          "-46.8849875",
#          "168.095957",
#          "168.0959605"
#       ],
#       "lat": "-46.8849886",
#       "lon": "168.09595875",
#       "display_name": "Area 51, Stewart Island/Rakiura Community, Southland District, Southland, New Zealand / Aotearoa",
#       "class": "landuse",
#       "type": "military",
#       "importance": 0.39999999999999997
#    },
#    {
#       "place_id": 4101902,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 446907522,
#       "boundingbox": [
#          "51.4479828",
#          "51.4480828",
#          "5.456515",
#          "5.456615"
#       ],
#       "lat": "51.4480328",
#       "lon": "5.456565",
#       "display_name": "Area 51, 51, Klokgebouw, Strijp S, Strijp, Eindhoven, Noord-Brabant, Nederland, 561AB, Nederland",
#       "class": "leisure",
#       "type": "pitch",
#       "importance": 0.32043043518689396
#    },
#    {
#       "place_id": 119238442,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 126901531,
#       "boundingbox": [
#          "59.2780964",
#          "59.284886",
#          "18.200624",
#          "18.2176933"
#       ],
#       "lat": "59.2827407",
#       "lon": "18.2093433",
#       "display_name": "Area 51, Kolar\u00e4ngen, \u00c4lta, Nacka kommun, Stockholms l\u00e4n, 131 33, Sverige",
#       "class": "highway",
#       "type": "path",
#       "importance": 0.27499999999999997
#    },
#    {
#       "place_id": 312703663,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 736887124,
#       "boundingbox": [
#          "52.0807917",
#          "52.0864254",
#          "5.7252985",
#          "5.7342303"
#       ],
#       "lat": "52.0820049",
#       "lon": "5.7282999",
#       "display_name": "Area 51, Wekerom, Ede, Gelderland, Nederland, 6733SB, Nederland",
#       "class": "highway",
#       "type": "path",
#       "importance": 0.27499999999999997
#    },
#    {
#       "place_id": 121190708,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 134150004,
#       "boundingbox": [
#          "40.3437909",
#          "40.3487982",
#          "-111.6592216",
#          "-111.6494009"
#       ],
#       "lat": "40.3476096",
#       "lon": "-111.6548849",
#       "display_name": "Area 51, Lindon, Utah County, Utah, 84042-1526, United States",
#       "class": "highway",
#       "type": "path",
#       "importance": 0.27499999999999997
#    },
#    {
#       "place_id": 200235066,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 500494056,
#       "boundingbox": [
#          "-23.2651377",
#          "-23.2641725",
#          "-45.8949321",
#          "-45.8942923"
#       ],
#       "lat": "-23.2646399",
#       "lon": "-45.89462055168171",
#       "display_name": "\u00c1rea 51, Campo dos Alem\u00e3es, S\u00e3o Jos\u00e9 dos Campos, Regi\u00e3o Imediata de S\u00e3o Jos\u00e9 dos Campos, Regi\u00e3o Metropolitana do Vale do Para\u00edba e Litoral Norte, Regi\u00e3o Geogr\u00e1fica Intermedi\u00e1ria de S\u00e3o Jos\u00e9 dos Campos, S\u00e3o Paulo, Regi\u00e3o Sudeste, Brasil",
#       "class": "leisure",
#       "type": "park",
#       "importance": 0.25
#    }
# ]

# %%
print(data_json[0]["osm_id"])
# Out:
# 9625443

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(data_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
data_way = data.json()
print(json.dumps(data_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1008165 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 9625443,
#          "timestamp": "2020-10-30T22:03:46Z",
#          "version": 4,
#          "changeset": 93312621,
#          "user": "GJF85",
#          "uid": 1333408,
#          "nodes": [
#             75127847,
#             75127845,
#             75127844,
#             1391851276,
#             75127843,
#             75127842,
#             75102228
#          ],
#          "tags": {
#             "highway": "residential",
#             "maxspeed": "25 mph",
#             "oneway": "yes",
#             "tiger:cfcc": "A41",
#             "tiger:county": "Cass, ND",
#             "tiger:reviewed": "no"
#          }
#       }
#    ]
# }
